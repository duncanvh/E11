# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
from google.colab import files
uploaded = files.upload()
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-504947ee-e1ba-44ed-846f-a1fcb0f940cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-504947ee-e1ba-44ed-846f-a1fcb0f940cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
outdata = pd.read_csv('outsidedata.csv')
indata = pd.read_csv('Weather_AQI_outside5.csv')
outdata = outdata.loc[1:,:]
indata = indata.loc[1:,:]
display(outdata)
display(indata)
#The data from the 1st row are inaccurate and act as outliers so we removed this line.
# Out:
#               time  PM1  PM2.5  PM10  BM680 Temp  BM680 Gas  BM680 Humidity  \
# 1    2 / 21 / 2025    0      1     1   23.127266      14678       36.970113
# 2    2 / 21 / 2025    0      1     1   23.161445      22550       36.477029
# 3    2 / 21 / 2025    0      1     1   23.187422      33798       35.914106
# 4    2 / 21 / 2025    0      1     1   23.206758      43284       35.381869
# 5    2 / 21 / 2025    0      1     1   23.217109      55998       34.862292
# ..             ...  ...    ...   ...         ...        ...             ...
# 295  2 / 21 / 2025    2      2     2   19.780391     301636       34.507801
# 296  2 / 21 / 2025    2      2     2   19.775312     301111       34.489958
# 297  2 / 21 / 2025    2      3     3   19.771602     301373       34.483827
# 298  2 / 21 / 2025    2      3     3   19.768086     300069       34.471922
# 299  2 / 21 / 2025    2      3     3   19.764961     299033       34.489015
#
#      BM680 Pressure  BM680 Altitude
# ...

# %%
pm1out = outdata.loc[:,'PM1']
pm1in = indata.loc[:,'PM 1.0']
plt.plot(pm1out,label = "Our Data")
plt.plot(pm1in,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("PM1")
plt.legend()
plt.show()
PM1SDout = np.std(pm1out)
PM1SDin = np.std(pm1in)

# %%
pm1out = outdata.loc[:,'PM1']
pm1in = indata.loc[:,'PM 1.0']
plt.hist(pm1out,label = "Our Data", alpha=0.5)
plt.hist(pm1in,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("PM1")
plt.legend()

# %%
pm25out = outdata.loc[:,'PM2.5']
pm25in = indata.loc[:,'PM 2.5']
plt.plot(pm25out,label = "Our Data")
plt.plot(pm25in,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("PM2.5")
plt.legend()
plt.show()

# %%
plt.hist(pm25out,label = "Our Data", alpha=0.5)
plt.hist(pm25in,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("PM2.5")
plt.legend()
plt.show()

# %%
pm10out = outdata.loc[:,'PM10']
pm10in = indata.loc[:,'PM 10']
plt.plot(pm10out,label = "Our Data")
plt.plot(pm10in,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("PM10")
plt.legend()
plt.show()

# %%
plt.hist(pm10out,label = "Our Data", alpha=0.5)
plt.hist(pm10in,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("PM10")
plt.legend()
plt.show()

# %%
tempout = outdata.loc[:,'BM680 Temp']
tempin = indata.loc[:,'Temp']
plt.plot(tempout,label = "Our Data")
plt.plot(tempin,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("Temperature(℃)")
plt.legend()
plt.show()

# %%
plt.hist(tempout,label = "Our Data", bins = "auto", alpha=0.5)
plt.hist(tempin,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("Temperature(℃)")
plt.legend()

# %%
gasout = outdata.loc[:,'BM680 Gas']
gasin = indata.loc[:,'Gas']
plt.plot(gasout,label = "Our Data")
plt.plot(gasin,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("Gas")
plt.legend()
plt.show()

# %%
plt.hist(gasout,label = "Our Data", bins = "auto", alpha=0.5)
plt.hist(gasin,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("Gas")
plt.legend()
plt.show()

# %%
humidout = outdata.loc[:,'BM680 Humidity']
humidin = indata.loc[:,'Humidity']
plt.plot(humidout,label = "Our Data")
plt.plot(humidin,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("Humidity(%)")
plt.legend()
plt.show()

# %%
plt.hist(humidout,label = "Our Data", bins = "auto", alpha=0.5)
plt.hist(humidin,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("Humidity(%)")
plt.legend()
plt.show()

# %%
pressureout = outdata.loc[:,'BM680 Pressure']
pressurein = indata.loc[:,'Pressure']
plt.plot(pressureout,label = "Our Data")
plt.plot(pressurein,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("Pressure(kPa)")
plt.legend()
plt.show()

# %%
plt.hist(pressureout,label = "Our Data", bins = "auto", alpha=0.5)
plt.hist(pressurein,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("Pressure")
plt.legend()
plt.show()

# %%
alout = outdata.loc[:,'BM680 Altitude']
alin = indata.loc[:,'Alt']
plt.plot(alout,label = "Our Data")
plt.plot(alin,label = "Their Data")
plt.xlabel("Time(seconds)")
plt.ylabel("Altitude(Meters)")
plt.legend()
plt.show()

# %%
plt.hist(alout,label = "Our Data", bins = "auto", alpha=0.5)
plt.hist(alin,label = "Their Data", alpha=0.5)
plt.xlabel("Time(seconds)")
plt.ylabel("Altitude")
plt.legend()
plt.show()

# %%
print("PM1 Standard Deviation Our Data: ", PM1SDout)
print("PM1 Standard Deviation Their Data: ",PM1SDin)
print("PM1 Mean Our Data: ", np.mean(pm1out))
print("PM1 Mean Their Data: ", np.mean(pm1in))
# Out:
# PM1 Standard Deviation Our Data:  0.710983615400519
# PM1 Standard Deviation Their Data:  0.5285550840170833
# PM1 Mean Our Data:  0.9464882943143813
# PM1 Mean Their Data:  0.6755852842809364

# %%
print("PM2.5 Standard Deviation Our Data: ", np.std(pm25out))
print("PM2.5 Standard Deviation Their Data: ",np.std(pm25in))
print("PM2.5 Mean Our Data: ", np.mean(pm25out))
print("PM2.5 Mean Their Data: ", np.mean(pm25in))
# Out:
# PM2.5 Standard Deviation Our Data:  0.9649046791312591
# PM2.5 Standard Deviation Their Data:  0.5651877057768221
# PM2.5 Mean Our Data:  1.5351170568561874
# PM2.5 Mean Their Data:  1.274247491638796

# %%
print("PM10 Standard Deviation Our Data: ", np.std(pm10out))
print("PM10 Standard Deviation Their Data: ",np.std(pm10in))
print("PM10 Mean Our Data: ", np.mean(pm10out))
print("PM10 Mean Their Data: ", np.mean(pm10in))
# Out:
# PM10 Standard Deviation Our Data:  0.9649046791312591
# PM10 Standard Deviation Their Data:  0.7190090980397591
# PM10 Mean Our Data:  1.5351170568561874
# PM10 Mean Their Data:  1.585284280936455

# %%
print("Temperature Standard Deviation Our Data: ", np.std(tempout))
print("Temperature Standard Deviation Their Data: ",np.std(tempin))
print("Temperature Mean Our Data: ", np.mean(tempout))
print("Temperature Mean Their Data: ", np.mean(tempin))
# Out:
# Temperature Standard Deviation Our Data:  0.7764245252532725
# Temperature Standard Deviation Their Data:  1.0815075685210136
# Temperature Mean Our Data:  20.632727842809366
# Temperature Mean Their Data:  19.707280387750835

# %%
print("Gas Standard Deviation Our Data: ", np.std(gasout))
print("Gas Standard Deviation Their Data: ",np.std(gasin))
print("Gas Mean Our Data: ", np.mean(gasout))
print("Gas Mean Their Data: ", np.mean(gasin))
# Out:
# Gas Standard Deviation Our Data:  51461.38959000144
# Gas Standard Deviation Their Data:  23981.377875455906
# Gas Mean Our Data:  252751.16722408027
# Gas Mean Their Data:  169325.3177257525

# %%
print("Humidity Standard Deviation Our Data: ", np.std(humidout))
print("Humidity Standard Deviation Their Data: ",np.std(humidin))
print("Humidity Mean Our Data: ", np.mean(humidout))
print("Humidity Mean Their Data: ", np.mean(humidin))
# Out:
# Humidity Standard Deviation Our Data:  1.2960212453678026
# Humidity Standard Deviation Their Data:  2.165480484811969
# Humidity Mean Our Data:  34.24750104678748
# Humidity Mean Their Data:  38.228958257824786

# %%
print("Pressure Standard Deviation Our Data: ", np.std(pressureout))
print("Pressure Standard Deviation Their Data: ",np.std(pressurein))
print("Pressure Mean Our Data: ", np.mean(pressureout))
print("Pressure Mean Their Data: ", np.mean(pressurein))
# Out:
# Pressure Standard Deviation Our Data:  0.01685094735770631
# Pressure Standard Deviation Their Data:  0.022151262101731503
# Pressure Mean Our Data:  1009.2891367263763
# Pressure Mean Their Data:  1009.1813742939561

# %%
print("Altitude Standard Deviation Outdoor: ", np.std(alout))
print("Altitude Standard Deviation Their Data: ",np.std(alin))
print("Altitude Mean Our Data: ", np.mean(alout))
print("Altitude Mean Their Data: ", np.mean(alin))
# Out:
# Altitude Standard Deviation Outdoor:  0.14074154848996132
# Altitude Standard Deviation Their Data:  0.18502529360914768
# Altitude Mean Our Data:  33.029207894944804
# Altitude Mean Their Data:  33.92929328328956
