# %%
import math
import numpy as np 
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
outdata = pd.read_csv('outsidedata.csv')
indata = pd.read_csv('insidedata.csv')
outdata = outdata.loc[1:,:]
indata = indata.loc[1:,:]
display(outdata)
#The data from the 1st row are inaccurate and act as outliers so we removed this line.
# Out:
#               time  PM1  PM2.5  PM10  BM680 Temp  BM680 Gas  BM680 Humidity  \
# 1    2 / 21 / 2025    0      1     1   23.127266      14678       36.970113
# 2    2 / 21 / 2025    0      1     1   23.161445      22550       36.477029
# 3    2 / 21 / 2025    0      1     1   23.187422      33798       35.914106
# 4    2 / 21 / 2025    0      1     1   23.206758      43284       35.381869
# 5    2 / 21 / 2025    0      1     1   23.217109      55998       34.862292
# ..             ...  ...    ...   ...         ...        ...             ...
# 295  2 / 21 / 2025    2      2     2   19.780391     301636       34.507801
# 296  2 / 21 / 2025    2      2     2   19.775312     301111       34.489958
# 297  2 / 21 / 2025    2      3     3   19.771602     301373       34.483827
# 298  2 / 21 / 2025    2      3     3   19.768086     300069       34.471922
# 299  2 / 21 / 2025    2      3     3   19.764961     299033       34.489015
#
#      BM680 Pressure  BM680 Altitude
# ...

# %%
pm1out = outdata.loc[:,'PM1']
pm1in = indata.loc[:,'PM1']
plt.plot(pm1out,label = "outside")
plt.plot(pm1in,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("PM1")
plt.legend()
plt.show()
PM1SDout = np.std(pm1out)
PM1SDin = np.std(pm1in)

# %%
pm1out = outdata.loc[:,'PM1']
pm1in = indata.loc[:,'PM1']
plt.hist(pm1out,label = "outside")
plt.hist(pm1in,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("PM1")
plt.legend()

# %%
pm25out = outdata.loc[:,'PM2.5']
pm25in = indata.loc[:,'PM2.5']
plt.plot(pm25out,label = "outside")
plt.plot(pm25in,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("PM2.5")
plt.legend()
plt.show()

# %%
plt.hist(pm25out,label = "outside")
plt.hist(pm25in,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("PM2.5")
plt.legend()
plt.show()

# %%
pm10out = outdata.loc[:,'PM10']
pm10in = indata.loc[:,'PM10']
plt.plot(pm10out,label = "outside")
plt.plot(pm10in,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("PM10")
plt.legend()
plt.show()

# %%
plt.hist(pm10out,label = "outside")
plt.hist(pm10in,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("PM10")
plt.legend()
plt.show()

# %%
tempout = outdata.loc[:,'BM680 Temp']
tempin = indata.loc[:,'BM680 Temp']
plt.plot(tempout,label = "outside")
plt.plot(tempin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Temperature(℃)")
plt.legend()
plt.show()

# %%
plt.hist(tempout,label = "outside", bins = "auto")
plt.hist(tempin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Temperature(℃)")
plt.legend()

# %%
gasout = outdata.loc[:,'BM680 Gas']
gasin = indata.loc[:,'BM680 Gas']
plt.plot(gasout,label = "outside")
plt.plot(gasin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Gas")
plt.legend()
plt.show()

# %%
plt.hist(gasout,label = "outside", bins = "auto")
plt.hist(gasin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Gas")
plt.legend()
plt.show()

# %%
humidout = outdata.loc[:,'BM680 Humidity']
humidin = indata.loc[:,'BM680 Humidity']
plt.plot(humidout,label = "outside")
plt.plot(humidin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Humidity(%)")
plt.legend()
plt.show()

# %%
plt.hist(humidout,label = "outside", bins = "auto")
plt.hist(humidin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Humidity(%)")
plt.legend()
plt.show()

# %%
pressureout = outdata.loc[:,'BM680 Pressure']
pressurein = indata.loc[:,'BM680 Pressure']
plt.plot(pressureout,label = "outside")
plt.plot(pressurein,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Pressure(kPa)")
plt.legend()
plt.show()

# %%
plt.hist(pressureout,label = "outside", bins = "auto")
plt.hist(pressurein,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Pressure")
plt.legend()
plt.show()

# %%
alout = outdata.loc[:,'BM680 Altitude']
alin = indata.loc[:,'BM680 Altitude']
plt.plot(alout,label = "outside")
plt.plot(alin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Altitude(Meters)")
plt.legend()
plt.show()

# %%
plt.hist(alout,label = "outside", bins = "auto")
plt.hist(alin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Altitude")
plt.legend()
plt.show()

# %%
print("PM1 Standard Deviation Outdoor: ", PM1SDout)
print("PM1 Standard Deviation Indoor: ",PM1SDin)
print("PM1 Mean Outdoor: ", np.mean(pm1out))
print("PM1 Mean Indoor: ", np.mean(pm1in))
# Out:
# PM1 Standard Deviation Outdoor:  0.7109836154005194
# PM1 Standard Deviation Indoor:  0.4822320337403846
# PM1 Mean Outdoor:  0.9464882943143813
# PM1 Mean Indoor:  0.6321070234113713

# %%
print("PM2.5 Standard Deviation Outdoor: ", np.std(pm25out))
print("PM2.5 Standard Deviation Indoor: ",np.std(pm25in))
print("PM2.5 Mean Outdoor: ", np.mean(pm25out))
print("PM2.5 Mean Indoor: ", np.mean(pm25in))
# Out:
# PM2.5 Standard Deviation Outdoor:  0.9649046791312591
# PM2.5 Standard Deviation Indoor:  0.6717497665847096
# PM2.5 Mean Outdoor:  1.5351170568561874
# PM2.5 Mean Indoor:  1.1538461538461537

# %%
print("PM10 Standard Deviation Outdoor: ", np.std(pm10out))
print("PM10 Standard Deviation Indoor: ",np.std(pm10in))
print("PM10 Mean Outdoor: ", np.mean(pm10out))
print("PM10 Mean Indoor: ", np.mean(pm10in))
# Out:
# PM10 Standard Deviation Outdoor:  0.9649046791312591
# PM10 Standard Deviation Indoor:  0.71604718512449
# PM10 Mean Outdoor:  1.5351170568561874
# PM10 Mean Indoor:  1.3043478260869565

# %%
print("Temperature Standard Deviation Outdoor: ", np.std(tempout))
print("Temperature Standard Deviation Indoor: ",np.std(tempin))
print("Temperature Mean Outdoor: ", np.mean(tempout))
print("Temperature Mean Indoor: ", np.mean(tempin))
# Out:
# Temperature Standard Deviation Outdoor:  0.7764245252532727
# Temperature Standard Deviation Indoor:  0.03885448527523758
# Temperature Mean Outdoor:  20.632727842809366
# Temperature Mean Indoor:  24.15204026442308

# %%
print("Gas Standard Deviation Outdoor: ", np.std(gasout))
print("Gas Standard Deviation Indoor: ",np.std(gasin))
print("Gas Mean Outdoor: ", np.mean(gasout))
print("Gas Mean Indoor: ", np.mean(gasin))
# Out:
# Gas Standard Deviation Outdoor:  51461.38959000144
# Gas Standard Deviation Indoor:  47669.1814381445
# Gas Mean Outdoor:  252751.16722408027
# Gas Mean Indoor:  169176.59866220737

# %%
print("Humidity Standard Deviation Outdoor: ", np.std(humidout))
print("Humidity Standard Deviation Indoor: ",np.std(humidin))
print("Humidity Mean Outdoor: ", np.mean(humidout))
print("Humidity Mean Indoor: ", np.mean(humidin))
# Out:
# Humidity Standard Deviation Outdoor:  1.2960212453678022
# Humidity Standard Deviation Indoor:  0.6415822474990641
# Humidity Mean Outdoor:  34.24750104678748
# Humidity Mean Indoor:  34.7162953302642

# %%
print("Pressure Standard Deviation Outdoor: ", np.std(pressureout))
print("Pressure Standard Deviation Indoor: ",np.std(pressurein))
print("Pressure Mean Outdoor: ", np.mean(pressureout))
print("Pressure Mean Indoor: ", np.mean(pressurein))
# Out:
# Pressure Standard Deviation Outdoor:  0.016850947357706307
# Pressure Standard Deviation Indoor:  0.0082026728914402
# Pressure Mean Outdoor:  1009.2891367263763
# Pressure Mean Indoor:  1010.2974786198178

# %%
print("Altitude Standard Deviation Outdoor: ", np.std(alout))
print("Altitude Standard Deviation Indoor: ",np.std(alin))
print("Altitude Mean Outdoor: ", np.mean(alout))
print("Altitude Mean Indoor: ", np.mean(alin))
# Out:
# Altitude Standard Deviation Outdoor:  0.14074154848996134
# Altitude Standard Deviation Indoor:  0.06845443535917173
# Altitude Mean Outdoor:  33.029207894944804
# Altitude Mean Indoor:  24.610809440400296
