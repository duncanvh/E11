# %%
import math
import numpy as np 
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
outdata = pd.read_csv('busstopdata.csv')
indata = pd.read_csv('insidedata.csv')
outdata = outdata.loc[1:,:]
indata = indata.loc[1:,:]
display(outdata)
#The data from the 1st row are inaccurate and act as outliers so we removed this line.
# Out:
#               time  PM1  PM2.5  PM10  BM680 Temp  BM680 Gas  BM680 Humidity  \
# 1    2 / 28 / 2025    2      3     3   24.175508       2538       41.643475
# 2    2 / 28 / 2025    2      3     3   24.242891       3868       41.583755
# 3    2 / 28 / 2025    3      4     4   24.319648       5108       41.476270
# 4    2 / 28 / 2025    3      4     4   24.394258       6777       41.344212
# 5    2 / 28 / 2025    3      4     4   24.465742       8521       41.211894
# ..             ...  ...    ...   ...         ...        ...             ...
# 295  2 / 28 / 2025   13     20    22   27.154023     157226       38.162865
# 296  2 / 28 / 2025   13     20    22   27.150117     156667       38.138446
# 297  2 / 28 / 2025   13     19    22   27.146602     157930       38.060077
# 298  2 / 28 / 2025   13     19    22   27.141914     159358       37.975629
# 299  2 / 28 / 2025   13     19    22   27.137812     158927       37.855341
#
#      BM680 Pressure  BM680 Altitude
# ...

# %%
pm1out = outdata.loc[:,'PM1']
pm1in = indata.loc[:,'PM1']
plt.plot(pm1out,label = "Bus stop")
plt.plot(pm1in,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("PM1")
plt.legend()
plt.show()
PM1SDout = np.std(pm1out)
PM1SDin = np.std(pm1in)

# %%
pm1out = outdata.loc[:,'PM1']
pm1in = indata.loc[:,'PM1']
plt.hist(pm1out,label = "Bus Stop", bins = "auto")
plt.hist(pm1in,label = "Classroom", bins = "auto")
plt.xlabel("Time(seconds)")
plt.ylabel("PM1")
plt.legend()

# %%
pm25out = outdata.loc[:,'PM2.5']
pm25in = indata.loc[:,'PM2.5']
plt.plot(pm25out,label = "Bus Stop")
plt.plot(pm25in,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("PM2.5")
plt.legend()
plt.show()

# %%
plt.hist(pm25out,label = "Bus Stop", bins = 'auto')
plt.hist(pm25in,label = "Classroom", bins = 'auto')
plt.xlabel("Time(seconds)")
plt.ylabel("PM2.5")
plt.legend()
plt.show()

# %%
pm10out = outdata.loc[:,'PM10']
pm10in = indata.loc[:,'PM10']
plt.plot(pm10out,label = "Bus Stop")
plt.plot(pm10in,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("PM10")
plt.legend()
plt.show()

# %%
plt.hist(pm10out,label = "Bus Stop", bins = 'auto')
plt.hist(pm10in,label = "Classroom", bins = 'auto')
plt.xlabel("Time(seconds)")
plt.ylabel("PM10")
plt.legend()
plt.show()

# %%
tempout = outdata.loc[:,'BM680 Temp']
tempin = indata.loc[:,'BM680 Temp']
plt.plot(tempout,label = "Bus Stop")
plt.plot(tempin,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("Temperature(℃)")
plt.legend()
plt.show()

# %%
plt.hist(tempout,label = "Bus Stop", bins = "auto")
plt.hist(tempin,label = "Classroom", bins = 1)
plt.xlabel("Time(seconds)")
plt.ylabel("Temperature(℃)")
plt.legend()

# %%
gasout = outdata.loc[:,'BM680 Gas']
gasin = indata.loc[:,'BM680 Gas']
plt.plot(gasout,label = "Bus Stop")
plt.plot(gasin,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("Gas")
plt.legend()
plt.show()

# %%
plt.hist(gasout,label = "Bus Stop", bins = "auto")
plt.hist(gasin,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("Gas")
plt.legend()
plt.show()

# %%
humidout = outdata.loc[:,'BM680 Humidity']
humidin = indata.loc[:,'BM680 Humidity']
plt.plot(humidout,label = "Bus Stop")
plt.plot(humidin,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("Humidity(%)")
plt.legend()
plt.show()

# %%
plt.hist(humidout,label = "Bus Stop", bins = "auto")
plt.hist(humidin,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("Humidity(%)")
plt.legend()
plt.show()

# %%
pressureout = outdata.loc[:,'BM680 Pressure']
pressurein = indata.loc[:,'BM680 Pressure']
plt.plot(pressureout,label = "Bus Stop")
plt.plot(pressurein,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("Pressure(kPa)")
plt.legend()
plt.show()

# %%
plt.hist(pressureout,label = "Bus Stop", bins = 1)
plt.hist(pressurein,label = "Classroom", bins = 1)
plt.xlabel("Time(seconds)")
plt.ylabel("Pressure")
plt.legend()
plt.show()

# %%
alout = outdata.loc[:,'BM680 Altitude']
alin = indata.loc[:,'BM680 Altitude']
plt.plot(alout,label = "Bus Stop")
plt.plot(alin,label = "Classroom")
plt.xlabel("Time(seconds)")
plt.ylabel("Altitude(Meters)")
plt.legend()
plt.show()

# %%
plt.hist(alout,label = "outside", bins = "auto")
plt.hist(alin,label = "inside")
plt.xlabel("Time(seconds)")
plt.ylabel("Altitude")
plt.legend()
plt.show()

# %%
print("PM1 Standard Deviation at the Bus Stop: ", PM1SDout)
print("PM1 Standard Deviation Indoor: ",PM1SDin)
print("PM1 Mean at the Bus Stop: ", np.mean(pm1out))
print("PM1 Mean Indoor: ", np.mean(pm1in))
# Out:
# PM1 Standard Deviation at the Bus Stop:  3.387763417627419
# PM1 Standard Deviation Indoor:  0.4822320337403846
# PM1 Mean at the Bus Stop:  12.177257525083611
# PM1 Mean Indoor:  0.6321070234113713

# %%
print("PM2.5 Standard Deviation at the Bus Stop: ", np.std(pm25out))
print("PM2.5 Standard Deviation Indoor: ",np.std(pm25in))
print("PM2.5 Mean at the Bus Stop: ", np.mean(pm25out))
print("PM2.5 Mean Indoor: ", np.mean(pm25in))
# Out:
# PM2.5 Standard Deviation at the Bus Stop:  5.215150449231401
# PM2.5 Standard Deviation Indoor:  0.6717497665847096
# PM2.5 Mean at the Bus Stop:  17.54515050167224
# PM2.5 Mean Indoor:  1.1538461538461537

# %%
print("PM10 Standard Deviation at the Bus Stop: ", np.std(pm10out))
print("PM10 Standard Deviation Indoor: ",np.std(pm10in))
print("PM10 Mean at the Bus Stop: ", np.mean(pm10out))
print("PM10 Mean Indoor: ", np.mean(pm10in))
# Out:
# PM10 Standard Deviation at the Bus Stop:  5.7800267365162386
# PM10 Standard Deviation Indoor:  0.71604718512449
# PM10 Mean at the Bus Stop:  18.65886287625418
# PM10 Mean Indoor:  1.3043478260869565

# %%
print("Temperature Standard Deviation at the Bus Stop: ", np.std(tempout))
print("Temperature Standard Deviation Indoor: ",np.std(tempin))
print("Temperature Mean at the Bus Stop: ", np.mean(tempout))
print("Temperature Mean Indoor: ", np.mean(tempin))
# Out:
# Temperature Standard Deviation at the Bus Stop:  0.6896499281626318
# Temperature Standard Deviation Indoor:  0.03885448527523758
# Temperature Mean at the Bus Stop:  26.31256754285117
# Temperature Mean Indoor:  24.15204026442308

# %%
print("Gas Standard Deviation at the Bus Stop: ", np.std(gasout))
print("Gas Standard Deviation Indoor: ",np.std(gasin))
print("Gas Mean at the Bus Stop: ", np.mean(gasout))
print("Gas Mean Indoor: ", np.mean(gasin))
# Out:
# Gas Standard Deviation at the Bus Stop:  39988.7355625351
# Gas Standard Deviation Indoor:  47669.1814381445
# Gas Mean at the Bus Stop:  122782.39130434782
# Gas Mean Indoor:  169176.59866220737

# %%
print("Humidity Standard Deviation at the Bus Stop: ", np.std(humidout))
print("Humidity Standard Deviation Indoor: ",np.std(humidin))
print("Humidity Mean at the Bus Stop: ", np.mean(humidout))
print("Humidity Mean Indoor: ", np.mean(humidin))
# Out:
# Humidity Standard Deviation at the Bus Stop:  1.498445112855108
# Humidity Standard Deviation Indoor:  0.6415822474990641
# Humidity Mean at the Bus Stop:  39.55061957232252
# Humidity Mean Indoor:  34.7162953302642

# %%
print("Pressure Standard Deviation at the Bus Stop: ", np.std(pressureout))
print("Pressure Standard Deviation Indoor: ",np.std(pressurein))
print("Pressure Mean at the Bus Stop: ", np.mean(pressureout))
print("Pressure Mean Indoor: ", np.mean(pressurein))
# Out:
# Pressure Standard Deviation at the Bus Stop:  0.028375603702446267
# Pressure Standard Deviation Indoor:  0.0082026728914402
# Pressure Mean at the Bus Stop:  1001.3773716198376
# Pressure Mean Indoor:  1010.2974786198178

# %%
print("Altitude Standard Deviation at the Bus Stop: ", np.std(alout))
print("Altitude Standard Deviation Indoor: ",np.std(alin))
print("Altitude Mean at the Bus Stop: ", np.mean(alout))
print("Altitude Mean Indoor: ", np.mean(alin))
# Out:
# Altitude Standard Deviation at the Bus Stop:  0.23851087261958295
# Altitude Standard Deviation Indoor:  0.06845443535917173
# Altitude Mean at the Bus Stop:  99.3200049782911
# Altitude Mean Indoor:  24.610809440400296
